# %% [markdown]
# # 구글 드라이브 마운트 및 경로 바꾸기

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !cat /etc/issue
# Out:
# Ubuntu 22.04.3 LTS \n \l

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd /content/drive/MyDrive/yolov5_detection/yolov5/data

# !unzip -qq "/content/drive/MyDrive/yolov5_detection/yolov5/data/1st.zip"

# %%
# %ls
# Out:
# 1st_train/  3rd.zip           cropped_images/    ImageNet100.yaml  scripts/       VisDrone.yaml
# 1st_valid/  coco128-seg.yaml  data.zip           ImageNet10.yaml   SKU-110K.yaml  VOC.yaml
# 1st.zip     coco128.yaml      hyps/              ImageNet.yaml     train/         xView.yaml
# 2nd.zip     coco.yaml         ImageNet1000.yaml  Objects365.yaml   valid/

# %%
# %cd /content/drive/MyDrive/yolov5_detection/yolov5/

import os
os.getcwd()
# Out:
# /content/drive/MyDrive/yolov5_detection/yolov5
# '/content/drive/MyDrive/yolov5_detection/yolov5'

# %%
#!pip install --upgrade pip

# %% [markdown]
# ## 학습전 필요한 패키지 설치

# %%
# %pip install -q -r requirements.txt # 필요한 패키지 설치
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 38.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 44.2 MB/s eta 0:00:00

# %% [markdown]
# ## GPU 확인

# %%
import torch
print(torch.cuda.is_available())
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('학습진행 기기:',device)

print('gpu 개수:', torch.cuda.device_count())

print('graphic name:', torch.cuda.get_device_name(0))

cuda = torch.device('cuda')
print(cuda)
# Out:
# True
# 학습진행 기기: cuda:0
# gpu 개수: 1
# graphic name: NVIDIA L4
# cuda

# %%
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       55534100 kB
# MemFree:        33402432 kB
# MemAvailable:   53715096 kB

# %% [markdown]
# # 로거(Logging) WandB

# %%
#%env CLEARML_WEB_HOST=https://app.clear.ml
#%env CLEARML_API_HOST=https://api.clear.ml
#%env CLEARML_FILES_HOST=https://files.clear.ml
#%env CLEARML_API_ACCESS_KEY=00L17MTIHMLKLHJK4A3S
#%env CLEARML_API_SECRET_KEY=qvvlq5co9i1DhuydrtswUheE4jzANRgCf9a37gArk2FQnRQnQ1
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=00L17MTIHMLKLHJK4A3S
# env: CLEARML_API_SECRET_KEY=qvvlq5co9i1DhuydrtswUheE4jzANRgCf9a37gArk2FQnRQnQ1

# %%
# !pip install -q wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 kB 29.4 MB/s eta 0:00:00

# %%
# wandb_api_key
# %env WANDB_API_KEY=3e89c4e40ddc4fbeaa49fb0c7b5cfd12377cb367
# Out:
# env: WANDB_API_KEY=3e89c4e40ddc4fbeaa49fb0c7b5cfd12377cb367

# %%
import wandb

run = wandb.init(
    project="YOLOv5",
    id="m8xls8bp",
    resume="allow"
)
# Out:
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/content/drive/MyDrive/yolov5_detection/yolov5/wandb/run-20240605_065624-m8xls8bp</code>
# Resuming run <strong><a href='https://wandb.ai/so0916a/YOLOv5/runs/m8xls8bp' target="_blank">yolov5_1st_train_0</a></strong> to <a href='https://wandb.ai/so0916a/YOLOv5' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/so0916a/YOLOv5' target="_blank">https://wandb.ai/so0916a/YOLOv5</a>
#  View run at <a href='https://wandb.ai/so0916a/YOLOv5/runs/m8xls8bp' target="_blank">https://wandb.ai/so0916a/YOLOv5/runs/m8xls8bp</a>

# %% [markdown]
# # 1차 데이터 학습

# %% [markdown]
# ## 1차 데이터 학습 exp3

# %%
# !python train.py --img 736 --batch 8 --epochs 60 --data custom_dataset.yaml --weights yolov5s.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-03-18 03:13:45.999850: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 03:13:45.999894: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 03:13:46.001398: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# ## 1차 데이터 학습 exp4

# %%
# !python train.py --img 736 --batch 8 --epochs 100 --data custom_dataset.yaml --weights yolov5s.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-03-18 05:42:16.733766: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 05:42:16.733814: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 05:42:16.735299: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# ## 1차 데이터 학습 exp5

# %%
# !python train.py --img 1080 --batch 8 --epochs 100 --data custom_dataset.yaml --weights /content/drive/MyDrive/shkim/yolov5/runs/train/exp4/weights/best.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-03-19 01:00:26.977445: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 01:00:26.977492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 01:00:26.978949: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# ## 1차 데이터 학습 exp6

# %%
# !python train.py --img 1080 --batch 16 --epochs 100 --data custom_dataset.yaml --weights /content/drive/MyDrive/yolov5_detection/yolov5/runs/train/exp5/weights/best.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-06-05 07:00:51.648079: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 07:00:51.648132: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 07:00:51.650047: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# ...

# %%
# 1차 데이터에 대한 검증, YAML파일 수정 완료
# !python val.py --data custom_dataset.yaml --weights /content/drive/MyDrive/yolov5_detection/yolov5/runs/train/exp6/weights/best.pt
# Out:
# val: data=custom_dataset.yaml, weights=['/content/drive/MyDrive/yolov5_detection/yolov5/runs/train/exp6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov5_detection/yolov5/data/1st_valid/14597572_김현숙(1)SF_비흡인_vallecular1/labels.cache... 619 images, 0 backgrounds, 0 corrupt: 100% 619/619 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/yolov5_detection/yolov5/data/1st_valid/24340247_강완희(4)YP_비흡인_vallecular2/images/24340247_강완희(4)YP_image093.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## 1차 데이터 학습 exp2: 보리에서 학습한 .pt 파일을 활용
# -

# %%
# !python train.py --img 1080 --batch 16 --epochs 200 --data custom_dataset.yaml --weights train_exp8_best.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-03-19 08:01:35.078587: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 08:01:35.078632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 08:01:35.080007: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: so0916a. Use `wandb login --relogin` to force relogin
# ...

# %%
# 1차 데이터에 대한 검증, YAML파일 수정 완료
# !python val.py --data custom_dataset.yaml --weights /content/drive/MyDrive/shkim/yolov5/runs/train/exp7/weights/best.pt
# Out:
# val: data=custom_dataset.yaml, weights=['/content/drive/MyDrive/shkim/yolov5/runs/train/exp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 166 layers, 7062001 parameters, 0 gradients
# ...
# 100% 755k/755k [00:00<00:00, 4.82MB/s]
# val: Scanning /content/drive/MyDrive/shkim/yolov5/data/1st_valid/labels.cache... 675 images, 4 backgrounds, 0 corrupt: 100% 679/679 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/shkim/yolov5/data/1st_valid/images/24340247_강완희(4)YP_image093.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# # 검증 이미지 한장씩 저장
# - detect.py에 validation set을 넣어서 prediction 이미지 저장
# - validation label image를 저장

# %%
# !python val.py --data custom_dataset3.yaml --img 1080 --batch-size 1 --weights /content/drive/MyDrive/shkim/yolov5/runs/train/exp13/weights/best.pt
# Out:
# val: data=custom_dataset3.yaml, weights=['/content/drive/MyDrive/shkim/yolov5/runs/train/exp13/weights/best.pt'], batch_size=1, imgsz=1080, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 166 layers, 7062001 parameters, 0 gradients
# WARNING ⚠️ --img-size 1080 must be multiple of max stride 32, updating to 1088
# val: Scanning /content/drive/MyDrive/shkim/yolov5/data/3rd_valid/labels.cache... 1193 images, 20 backgrounds, 0 corrupt: 100% 1213/1213 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/shkim/yolov5/data/3rd_valid/images/27927869_김준자(1)SF_image054.jpg: 1 duplicate labels removed
# ...

# %%
# !python val.py --data custom_dataset_total.yaml --batch-size 1 --img 1080 --weights /content/drive/MyDrive/shkim/yolov5/runs/train/exp13/weights/best.pt
# Out:
# val: data=custom_dataset_total.yaml, weights=['/content/drive/MyDrive/shkim/yolov5/runs/train/exp13/weights/best.pt'], batch_size=1, imgsz=1080, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-294-gdb125a20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 166 layers, 7062001 parameters, 0 gradients
# WARNING ⚠️ --img-size 1080 must be multiple of max stride 32, updating to 1088
# val: Scanning /content/drive/MyDrive/shkim/yolov5/data/valid/labels.cache... 2157 images, 477 backgrounds, 0 corrupt: 100% 2634/2634 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/shkim/yolov5/data/valid/images/25918605_설창훈(1)SF_image073.jpg: 1 duplicate labels removed
# ...
